# %% [markdown]
# # Report Generation Example
#
# The following report is generated by loading up the model.

# %%
import jinja2
import capellambse
from IPython.display import Markdown

from IPython.core.display import HTML
#from IPython import display
import pandas as pd 


resources = {
    "EV_Thermal_System": "EV_Thermal_System/EV Thermal System",
}
path_to_model = "../EV Thermal System.aird"
model = capellambse.MelodyModel(path_to_model, resources=resources)
# Out:
# Ignoring file of unknown type, loaded model may be incomplete: EV Thermal System.traceability

# %% [markdown]
# Below defines a set of routines that use Jinga templates to generate html report.

# %%
import capellambse_helper

# %% [markdown]
# # Component Report
#
# The following generates report of the noted physical component.

# %%
from IPython import display as diag_display
lc = model.search("LogicalComponent").by_name("Vehicle")
#print(lc)
display(Markdown(f"\n\n**Dynamically Generated Context diagram of:**\n{lc.name}"))
display(lc.context_diagram)
# Out:
# **Dynamically Generated Context diagram of:**
# Vehicle
# <Diagram 'Context of Vehicle'>

# %%
#diagram_file ="../images/[LAB] Braking .jpg"
##display(diag_display.Image(filename=diagram_file) ) # Explicitly display the image

# %%
display(Markdown(f"\n\n**Report:**\n{lc.name}"))
capellambse_helper.Display_Component_Report(lc)
# Out:
# **Report:**
# Vehicle
#     <h1>Vehicle - <span style="font-size: 10px" > UUID: a2da5b5b-7409-40b6-bf87-5ff510c4a96d </span> </h2>
#     <p></p>
#
#         <p style="text-align: left;">No property values were identified.</p>
#
#
#     <p  >The table below identifies property values groups of Vehicle.</p>
#         <table  style="border: 2px solid black; width:100% " >
#             <tr>
#                 <th style="text-align:left ;border: 1px solid black" >Property Group Name </th>
#                 <th style="text-align:left ; border: 1px solid black">Property Summary</th>
#             </tr>
#
#
#
#                 <tr>
#                     <td style="text-align:left ; border: 1px solid black">Vehicle Properties</td>
#                     <td style="text-align:left ; border: 1px solid black"></td>
#                 </tr>
#                 <tr>
#                     <td style="text-align:right ; border: 1px solid black"> Properties of Vehicle Properties</td>
#                     <td style="text-align:left ; border: 1px solid black">
#                             <table  style="border: 1px solid black; width:100% " >
#                                 <tr>
#                                     <th style="text-align:left ;border: 1px solid black">Property Name  </th>
#                                     <th style="text-align:left ; border: 1px solid black"> Property Value </th>
#                                 </tr>
#
#                            </table>
#
#                   </td>
#                 </tr>
#
#                 <tr>
#                     <td style="text-align:left ; border: 1px solid black">NPI_Levels.CompLevelExtension</td>
#                     <td style="text-align:left ; border: 1px solid black"></td>
#                 </tr>
#                 <tr>
#                     <td style="text-align:right ; border: 1px solid black"> Properties of NPI_Levels.CompLevelExtension</td>
#                     <td style="text-align:left ; border: 1px solid black">
#                             <table  style="border: 1px solid black; width:100% " >
#                                 <tr>
#                                     <th style="text-align:left ;border: 1px solid black">Property Name  </th>
#                                     <th style="text-align:left ; border: 1px solid black"> Property Value </th>
#                                 </tr>
#
#                             <tr>
#                                 <td style="text-align:left ; border: 1px solid black">Level </td>
#                                 <td style="text-align:left ; border: 1px solid black">L5</td>
#                             </tr>
#
#                            </table>
#
#                   </td>
#                 </tr>
#
#
#            </table>
#          <p style="text-align: center;"><strong>Property Values Groups Vehicle</strong></p>
#
#     <h3> Vehicle Ports </h3>
